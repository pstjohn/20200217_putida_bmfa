# %%
import pandas as pd

# %%
import cobra.io
import gzip

with gzip.open('iJN1463.json.gz') as file:
    model = cobra.io.load_json_model(file)

# %%
model.genes[2].annotation
# Out:
# {'ncbigene': ['1041963'],
#  'ncbigi': ['26987960'],
#  'refseq_locus_tag': ['PP_1225'],
#  'refseq_name': ['queE'],
#  'sbo': 'SBO:0000243'}

# %%
model.metabolites.glyc_c.annotation
# Out:
# {'bigg.metabolite': ['glyc'],
#  'biocyc': ['META:GLYCEROL'],
#  'chebi': ['CHEBI:5448',
#   'CHEBI:14334',
#   'CHEBI:42998',
#   'CHEBI:17754',
#   'CHEBI:24351',
#   'CHEBI:131422'],
#  'envipath': ['32de3cf4-e3e6-4168-956e-32fa5ddb0ce1/compound/48edd8a9-6a4a-4900-b0cf-97b1ccaa1125',
#   '650babc9-9d68-4b73-9332-11972ca26f7b/compound/2e8c8093-3269-46b3-be2e-f1df9fdde25c'],
#  'hmdb': ['HMDB00131'],
#  'inchi_key': ['PEDCQBHIVMGVHV-UHFFFAOYSA-N'],
#  'kegg.compound': ['C00116'],
#  'kegg.drug': ['D00028'],
#  'metanetx.chemical': ['MNXM89612'],
#  'reactome.compound': ['192438', '76116'],
#  'sabiork': ['1303'],
#  'sbo': 'SBO:0000247',
#  'seed.compound': ['cpd00100']}

# %%
import requests
import json
from tqdm import tqdm

# %%
import warnings

# %%
import time

# %%
def parse_rest_response(url):

    response = requests.get(url)
    if response.status_code == 200:
        return json.loads(response.content.decode('utf-8'))
    else:
        return None
    
def parse_cid(cid, to='CHEBI'):
    response = parse_rest_response(f'http://cts.fiehnlab.ucdavis.edu/service/convert/PubChem%20CID/{to}/{cid}')
    if response:
        return response[0]['result']
    else:
        warnings.warn(f'Error with cid {cid}')
        return []


to_try = ['KEGG', 'ChEBI', 'BioCyc', 'InChIKey']

def iter_matches(unique_cids):
    for cid in tqdm(unique_cids):
        for db in to_try:
            for result in parse_cid(cid, to=db):
                time.sleep(1)
                yield pd.Series({
                    'cid': cid, 
                    'db': db, 
                    'identifier': result})

# %%
unique_cids = pd.Series(df_metabolite['Formal Type'].unique()).str.strip('cid:')
results_database = pd.DataFrame(iter_matches(unique_cids.values))
# Out:
#  70%|██████▉   | 87/125 [06:37<02:22,  3.75s/it]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14 UserWarning: Error with cid 8411366
# 100%|██████████| 125/125 [09:54<00:00,  4.76s/it]

# %%
unique_cids.shape
# Out:
# (125,)

# %%
results_database.to_csv('cid_matches.csv', index=False)

# %%
results_database
# Out:
#           cid        db                   identifier
# 0     5356793     ChEBI                  CHEBI:27036
# 1     5356793     ChEBI                  CHEBI:38407
# 2     5356793  InChIKey  TXXHDPDFNKHHGW-ZPUQHVIOSA-N
# 3        6912  InChIKey  HEBKCHPVOIAQTA-NGQZWQHPSA-N
# 4       86860  InChIKey  RTLDJXGEOSVJEX-UHFFFAOYSA-N
# ..        ...       ...                          ...
# 422  19782904      KEGG                       D00037
# 423  19782904     ChEBI                  CHEBI:30769
# 424  19782904  InChIKey  KRKNYBCHXYNGOX-UHFFFAOYSA-N
# 425     21363     ChEBI                  CHEBI:37277
# 426     21363  InChIKey  LJOODBDWMQKMFB-UHFFFAOYSA-N
#
# [427 rows x 3 columns]

# %%
def iter_model_annotations():
    for met in tqdm(model.metabolites.query('c', 'compartment')):
        for database, values in met.annotation.items():
            for value in values:
                yield pd.Series({
                    'metabolite': met.id, 
                    'db': database, 
                    'identifier': value})

# %%
model_annotations = pd.DataFrame(iter_model_annotations())
# Out:
# 100%|██████████| 1339/1339 [00:05<00:00, 243.27it/s]

# %%
model_annotations.db.unique()
# Out:
# array(['bigg.metabolite', 'biocyc', 'chebi', 'hmdb', 'inchi_key',
#        'kegg.compound', 'metanetx.chemical', 'reactome.compound',
#        'sabiork', 'sbo', 'seed.compound', 'envipath', 'lipidmaps', 'slm',
#        'kegg.drug', 'kegg.glycan'], dtype=object)

# %%
results_database.db.unique()
# Out:
# array(['ChEBI', 'InChIKey', 'KEGG', 'BioCyc'], dtype=object)

# %%
model_annotations['db'] = model_annotations.db.replace(
    {'biocyc': 'BioCyc',
     'chebi': 'ChEBI',
     'kegg.compound': 'KEGG',
     'inchi_key': 'InChIKey'
    })

# %%
model_annotations
# Out:
#       metabolite               db          identifier
# 0       10fthf_c  bigg.metabolite              10fthf
# 1       10fthf_c           BioCyc  META:10-FORMYL-THF
# 2       10fthf_c            ChEBI         CHEBI:19108
# 3       10fthf_c            ChEBI         CHEBI:15637
# 4       10fthf_c            ChEBI           CHEBI:698
# ...          ...              ...                 ...
# 28589   malttr_c              sbo                   0
# 28590   malttr_c              sbo                   2
# 28591   malttr_c              sbo                   4
# 28592   malttr_c              sbo                   7
# 28593   malttr_c    seed.compound            cpd01262
#
# [28594 rows x 3 columns]

# %%
merged_identifiers = results_database.merge(model_annotations, how='inner', on=['db', 'identifier'])

# %%
len(merged_identifiers.metabolite.unique())
# Out:
# 71

# %%
unique_merges = merged_identifiers = merged_identifiers.drop_duplicates(subset=['cid', 'metabolite'])
unique_merges
# Out:
#           cid    db identifier  metabolite
# 0     3035456  KEGG     C06473   2dhglcn_c
# 2          72  KEGG     C00230    34dhbz_c
# 3    22639876  KEGG     C01353      hco3_c
# 5     5280518  KEGG     C02480    ccmuac_c
# 7       10690  KEGG     C00257      glcn_c
# ..        ...   ...        ...         ...
# 163     91493  KEGG     C00345      6pgc_c
# 164       190  KEGG     C00147       ade_c
# 167      6083  KEGG     C00020       amp_c
# 169       289  KEGG     C00090  catechol_c
# 174  19782904  KEGG     C00158       cit_c
#
# [71 rows x 4 columns]

# %%
# manual matches
unique_merges_manual = unique_merges.append(pd.DataFrame((
    {'cid': '724', 'metabolite': '3pg'},
    {'cid': '6902', 'metabolite': 'arab__L_c'},
    {'cid': '439163', 'metabolite': 'fru_p'},
    {'cid': '6036', 'metabolite': 'udpgal_c'},
    {'cid': '7027', 'metabolite': '6pgl_c'})),
    ignore_index=True)

# %%
unique_merges_manual.to_csv('cid_to_bigg_matches.csv', index=False)

# %%
unique_mets = df_metabolite[['Formal Type', 'Measurement Type']].drop_duplicates()
unique_mets['cid'] = unique_mets['Formal Type'].str.strip('cid:')

# %%
unique_mets[~unique_mets.cid.isin(unique_merges_manual.cid)].merge(results_database.drop_duplicates(subset='cid'))
# Out:
#      Formal Type                                   Measurement Type       cid  \
# 0    cid:5356793                               (2E,4E)-muconic acid   5356793
# 1       cid:6912                   (2S,4R)-pentane-1,2,3,4,5-pentol      6912
# 2      cid:86860                  2-(2-furyl)-2-hydroxy-acetic acid     86860
# 3   cid:53440600                                hex-2-enedioic acid  53440600
# 4     cid:102424  (3S,4R,5S)-3,4,5,6-tetrahydroxy-2-keto-hexanoi...    102424
# 5     cid:345901                        2-methylpropane-1,2,3-triol    345901
# 6      cid:69507  [(2R,3R,4S)-2,3,4,6-tetrahydroxy-5-keto-hexyl]...     69507
# 7     cid:439958  [(2R,3R,4S,5R)-2,3,4,5-tetrahydroxy-6-keto-hex...    439958
# 8       cid:6251             (2R,3R,4R,5R)-hexane-1,2,3,4,5,6-hexol      6251
# 9    cid:5289590     (3~{S},4~{R})-1,3,4,5-tetrahydroxypentan-2-one   5289590
# 10    cid:128869  (2R,3S,4S,5R)-2,3,4,5,6-pentahydroxyhexanoic acid    128869
# 11  cid:22840032  (3~{S},4~{S},5~{S})-5-[(1~{S})-1,2-dihydroxyet...  22840032
# 12     cid:11005                                      myristic acid     11005
# 13     cid:66868                              21,22-dihydroporphine     66868
# 14   cid:5460677        (2R,3R,4R)-2,3,4,5-tetrahydroxyvaleric acid   5460677
# 15    cid:439665        (2~{S},3~{R})-2,3,4-trihydroxybutyraldehyde    439665
# 16    cid:123991                                2-aminoacrylic acid    123991
# 17     cid:76599  (2~{R},3~{R},4~{S},5~{R},6~{R})-2,3,4,5,6,7-he...     76599
# 18       cid:751                       2,3-dihydroxypropionaldehyde       751
# 19     cid:77982  [(2R,3R,4R)-2,3,4-trihydroxy-5-keto-pentyl] di...     77982
# 20       cid:754                      glyceryl dihydrogen phosphate       754
# 21   cid:6435863                                glycerol;oleic acid   6435863
# 22     cid:24699                        stearic acid glyceryl ester     24699
# 23      cid:6255  (2R,3S,4S,5R,6R)-2-methylol-6-[(2R,3S,4R,5R,6R...      6255
# 24   cid:5288441  (2S,3R,4R,5R)-4-[(2R,3R,4R,5S,6R)-3,4-dihydrox...   5288441
# 25   cid:5364509              (Z)-octadec-9-enoic acid methyl ester   5364509
# 26  cid:12691389                                   methyl phosphate  12691389
# 27    cid:439281  N-[(3S,4R,5S,6R)-2,4,5-trihydroxy-6-methylol-t...    439281
# 28    cid:445638                                   palmitoleic acid    445638
# 29      cid:6508  (3R,5R)-1,3,4,5-tetrahydroxycyclohexanecarboxy...      6508
# 30   cid:5081328                    thiazolidin-3-ium-4-carboxylate   5081328
# 31       cid:428                                 3-aminopropylamine       428
# 32  cid:57455226                          (~{E})-heptadec-10-enoate  57455226
# 33  cid:23368901                         5-hydroxy-1H-pyrazin-2-one  23368901
# 34        cid:43                             2-hydroxyglutaric acid        43
# 35      cid:8871                                         2-pyridone      8871
# 36  cid:25201103                      3-ammonio-2-methyl-propionate  25201103
# 37       cid:441                              3-hydroxybutyric acid       441
# 38     cid:26612                               3-hydroxycapric acid     26612
# 39     cid:26613                             3-hydroxycaprylic acid     26613
# 40      cid:7971                                       pyridin-3-ol      7971
# 41     cid:61743                                   dec-9-enoic acid     61743
# 42    cid:100714                                2-aminomalonic acid    100714
# 43     cid:94154                   (2R,4R)-pentane-1,2,3,4,5-pentol     94154
# 44  cid:92043261     disodium;(2-hydroxy-1-methyl-ethoxy) phosphate  92043261
# 45    cid:102018  (3-hydroxy-2-phosphonooxy-propyl) dihydrogen p...    102018
# 46      cid:2969                                        capric acid      2969
# 47     cid:21363                            2-cyclohexylacetic acid     21363
#
#           db                   identifier
# 0      ChEBI                  CHEBI:27036
# 1   InChIKey  HEBKCHPVOIAQTA-NGQZWQHPSA-N
# 2   InChIKey  RTLDJXGEOSVJEX-UHFFFAOYSA-N
# 3   InChIKey  HSBSUGYTMJWPAX-UHFFFAOYSA-N
# 4       KEGG                       C15673
# 5   InChIKey  OOJRTGIXWIUBGG-UHFFFAOYSA-N
# 6      ChEBI                  CHEBI:15946
# 7       KEGG                       C03251
# 8       KEGG                       C00392
# 9      ChEBI                  CHEBI:17140
# 10      KEGG                       C00880
# 11  InChIKey  SXZYCXMUPBBULW-FCAWWPLPSA-N
# 12      KEGG                       C06424
# 13  InChIKey  JZRYQZJSTWVBBD-UHFFFAOYSA-N
# 14      KEGG                       C01685
# 15     ChEBI                  CHEBI:28587
# 16      KEGG                       C02218
# 17  InChIKey  YPZMPEPLWKRVLD-PJEQPVAWSA-N
# 18      KEGG                       C02154
# 19     ChEBI                  CHEBI:17797
# 20      KEGG                       C03189
# 21  InChIKey  FABAOYOFJNAVHB-KVVVOXFISA-N
# 22      KEGG                       D01947
# 23      KEGG                       C01971
# 24  InChIKey  XJCCHWKNFMUJFE-CGQAXDJHSA-N
# 25      KEGG                       C03425
# 26     ChEBI                  CHEBI:59761
# 27      KEGG                       C00645
# 28      KEGG                       C08362
# 29  InChIKey  AAWZDTNXLSGCEK-LNVDRNJUSA-N
# 30      KEGG                       D08601
# 31      KEGG                       C00986
# 32    BioCyc                    CPD-15679
# 33  InChIKey  USHRADXTTYICIJ-UHFFFAOYSA-N
# 34      KEGG                       C02630
# 35      KEGG                       C02502
# 36      KEGG                       C05145
# 37     ChEBI                  CHEBI:20067
# 38  InChIKey  FYSSBMZUBSBFJL-UHFFFAOYSA-N
# 39     ChEBI                  CHEBI:37098
# 40    BioCyc                    CPD-12318
# 41     ChEBI                  CHEBI:32381
# 42      KEGG                       C00872
# 43      KEGG                       C01904
# 44  InChIKey  GHRQXJHBXKYCLZ-UHFFFAOYSA-L
# 45  InChIKey  IBPDKUYWDGDBQW-UHFFFAOYSA-N
# 46      KEGG                       C01571
# 47     ChEBI                  CHEBI:37277

# %%
pd.Series(model_annotations.metabolite.unique()).isin(merged_identifiers.metabolite).sum()
# Out:
# 71
